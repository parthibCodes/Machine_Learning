# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\parth\\OneDrive\\Desktop\\ML_CSV\\hairfall_dataset.csv")
df
# Out:
#      Age  Stress_Level  Diet_Score  Sleep_Hours  Genetic_Factor  \
# 0     56             6          10          6.5               0
# 1     46             8           1          7.2               0
# 2     32             5           2          8.7               0
# 3     25             4           6          7.9               0
# 4     38             2           9          9.7               0
# ..   ...           ...         ...          ...             ...
# 195   23             7           5          5.9               1
# 196   49             9           5          3.4               1
# 197   21             5           4          5.0               1
# 198   28             1           3          3.7               0
# 199   34            10           3          6.0               0
#
#      Hairwash_Freq  Hairfall
# 0                7         0
# 1                1         1
# 2                4         1
# 3                1         0
# 4                1         0
# ..             ...       ...
# 195              1         1
# 196              2         1
# 197              5         0
# 198              4         1
# 199              6         1
#
# [200 rows x 7 columns]

# %%
x = df.drop("Hairfall",axis="columns")
y = df.Hairfall

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[20,6,7,7,1,2]])
# Out:
# C:\Users\parth\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
X_test
# Out:
#      Age  Stress_Level  Diet_Score  Sleep_Hours  Genetic_Factor  Hairwash_Freq
# 119   22            10           4          7.8               0              4
# 22    50             8          10          4.5               1              5
# 189   50            10           6          5.9               0              5
# 185   45             3           1          5.9               1              6
# 163   56            10           7          4.7               1              6
# 164   23             6           9          5.5               0              2
# 50    34             6           8          9.6               0              2
# 115   54             1           9          4.4               0              3
# 90    25             6           8          9.4               1              7
# 133   21             8           5          7.3               0              1
# 123   44             8           5          5.2               0              6
# 17    41             4           9          9.3               1              3
# 192   19             5          10          7.8               0              7
# 3     25             4           6          7.9               0              1
# 68    31             6          10          3.9               0              7
# 117   20             2           9          4.9               0              7
# 181   54             8           7          6.3               1              5
# 183   19             2           3          6.9               0              1
# 159   44             9           1          5.1               1              2
# 194   49             5           6          8.3               1              5

# %%
model.score(X_test,y_test)
# Out:
# 0.9

# %%
model.predict(X_test)
# Out:
# array([1, 1, 1, 1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 0, 1, 1, 1, 1, 1, 1])

# %%
model.predict([[29, 8, 3, 5.2, 1, 4]])
# Out:
# C:\Users\parth\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         4
#            1       0.94      0.94      0.94        16
#
#     accuracy                           0.90        20
#    macro avg       0.84      0.84      0.84        20
# weighted avg       0.90      0.90      0.90        20

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(model,X_test,y_test)
